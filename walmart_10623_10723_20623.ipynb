# %% [markdown]
# ## WALMART DATA ANALYSIS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
train_df = pd.read_csv('train_walmart.csv')
stores = pd.read_csv('stores.csv')
features  = pd.read_csv('features.csv')

# %%
train_df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
train_df.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# dtype: int64

# %%
stores.isnull().sum()
# Out:
# Store    0
# Type     0
# Size     0
# dtype: int64

# %%
features.isnull().sum()
# Out:
# Store              0
# Date               0
# Temperature        0
# Fuel_Price         0
# MarkDown1       4158
# MarkDown2       5269
# MarkDown3       4577
# MarkDown4       4726
# MarkDown5       4140
# CPI              585
# Unemployment     585
# IsHoliday          0
# dtype: int64

# %%
features.shape
# Out:
# (8190, 12)

# %%
features.drop(['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5'], axis=1,inplace=True)

# %%
features.fillna(method='ffill',axis=0,inplace=True)

# %%
features.isnull().sum()
# Out:
# Store           0
# Date            0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# IsHoliday       0
# dtype: int64

# %%
## inner
df = train_df.merge(stores,how='inner',on=['Store'])

# %%
train_df.shape
# Out:
# (421570, 5)

# %%
df.shape
# Out:
# (421570, 7)

# %%
df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size'], dtype='object')

# %%
features.columns
# Out:
# Index(['Store', 'Date', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment',
#        'IsHoliday'],
#       dtype='object')

# %%
df = df.merge(features,how='inner',on=['Store','Date','IsHoliday'])

# %%
df
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1  2010-02-05      24924.50      False    A  151315
# 1           1     2  2010-02-05      50605.27      False    A  151315
# 2           1     3  2010-02-05      13740.12      False    A  151315
# 3           1     4  2010-02-05      39954.04      False    A  151315
# 4           1     5  2010-02-05      32229.38      False    A  151315
# ...       ...   ...         ...           ...        ...  ...     ...
# 421565     45    93  2012-10-26       2487.80      False    B  118221
# 421566     45    94  2012-10-26       5203.31      False    B  118221
# 421567     45    95  2012-10-26      56017.47      False    B  118221
# 421568     45    97  2012-10-26       6817.48      False    B  118221
# 421569     45    98  2012-10-26       1076.80      False    B  118221
#
#         Temperature  Fuel_Price         CPI  Unemployment
# 0             42.31       2.572  211.096358         8.106
# 1             42.31       2.572  211.096358         8.106
# 2             42.31       2.572  211.096358         8.106
# 3             42.31       2.572  211.096358         8.106
# 4             42.31       2.572  211.096358         8.106
# ...             ...         ...         ...           ...
# 421565        58.85       3.882  192.308899         8.667
# 421566        58.85       3.882  192.308899         8.667
# 421567        58.85       3.882  192.308899         8.667
# 421568        58.85       3.882  192.308899         8.667
# 421569        58.85       3.882  192.308899         8.667
#
# [421570 rows x 11 columns]

# %%
## date column in datetime - create new columns- year and week
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['week'] = df.Date.dt.isocalendar().week

# %%
df['year'] = df.Date.dt.isocalendar().year

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1 2010-02-05      24924.50      False    A  151315
# 1           1     2 2010-02-05      50605.27      False    A  151315
# 2           1     3 2010-02-05      13740.12      False    A  151315
# 3           1     4 2010-02-05      39954.04      False    A  151315
# 4           1     5 2010-02-05      32229.38      False    A  151315
# ...       ...   ...        ...           ...        ...  ...     ...
# 421565     45    93 2012-10-26       2487.80      False    B  118221
# 421566     45    94 2012-10-26       5203.31      False    B  118221
# 421567     45    95 2012-10-26      56017.47      False    B  118221
# 421568     45    97 2012-10-26       6817.48      False    B  118221
# 421569     45    98 2012-10-26       1076.80      False    B  118221
#
#         Temperature  Fuel_Price         CPI  Unemployment  week  year
# 0             42.31       2.572  211.096358         8.106     5  2010
# 1             42.31       2.572  211.096358         8.106     5  2010
# 2             42.31       2.572  211.096358         8.106     5  2010
# 3             42.31       2.572  211.096358         8.106     5  2010
# 4             42.31       2.572  211.096358         8.106     5  2010
# ...             ...         ...         ...           ...   ...   ...
# 421565        58.85       3.882  192.308899         8.667    43  2012
# 421566        58.85       3.882  192.308899         8.667    43  2012
# 421567        58.85       3.882  192.308899         8.667    43  2012
# 421568        58.85       3.882  192.308899         8.667    43  2012
# 421569        58.85       3.882  192.308899         8.667    43  2012
#
# [421570 rows x 13 columns]

# %%
### write the function that can take feature name as input and create a scatter plot of that gicen feature and weekly sales

# %%
def scatter(column):
    plt.figure()
    plt.scatter(df[column],df['Weekly_Sales'])
    plt.ylabel('weekly_sales')
    plt.xlabel(column)

# %%
scatter('Store')

# %%
scatter('Size')

# %%
df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'week', 'year'],
#       dtype='object')

# %%
scatter('Type')

# %%
################ line charts for weekly sales each year
###### avg weekly sales for the year 2012
x = df[df['year']==2010].groupby(['week'])['Weekly_Sales'].mean()
sns.lineplot(x.index,x.values,color='green')
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %%
y = df[df['year']==2011].groupby(['week'])['Weekly_Sales'].mean()
sns.lineplot(y.index,y.values,color='green')
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='week'>

# %%
z = df[df['year']==2012].groupby(['week'])['Weekly_Sales'].mean()
sns.lineplot(x=z.index,y=z.values,color='blue')
# Out:
# <AxesSubplot:xlabel='week'>

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x.index,x.values,color='blue')
sns.lineplot(y.index,y.values,color='red')
sns.lineplot(z.index,z.values,color='green')
plt.grid()
plt.xticks(np.arange(1,60,step=1))
plt.legend(['2010','2011','2012'])
plt.xlabel('week',fontsize=16)
plt.ylabel('sales',fontsize=16)
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'sales')

# %%
sns.distplot(x=df['Weekly_Sales'],color='red')
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:ylabel='Density'>

# %%
############################ plot the stores with highest average sales
########################### plot the dept with hughest average sales

# %%
df
# Out:
#         Store  Dept       Date  Weekly_Sales  IsHoliday Type    Size  \
# 0           1     1 2010-02-05      24924.50      False    A  151315
# 1           1     2 2010-02-05      50605.27      False    A  151315
# 2           1     3 2010-02-05      13740.12      False    A  151315
# 3           1     4 2010-02-05      39954.04      False    A  151315
# 4           1     5 2010-02-05      32229.38      False    A  151315
# ...       ...   ...        ...           ...        ...  ...     ...
# 421565     45    93 2012-10-26       2487.80      False    B  118221
# 421566     45    94 2012-10-26       5203.31      False    B  118221
# 421567     45    95 2012-10-26      56017.47      False    B  118221
# 421568     45    97 2012-10-26       6817.48      False    B  118221
# 421569     45    98 2012-10-26       1076.80      False    B  118221
#
#         Temperature  Fuel_Price         CPI  Unemployment  week  year
# 0             42.31       2.572  211.096358         8.106     5  2010
# 1             42.31       2.572  211.096358         8.106     5  2010
# 2             42.31       2.572  211.096358         8.106     5  2010
# 3             42.31       2.572  211.096358         8.106     5  2010
# 4             42.31       2.572  211.096358         8.106     5  2010
# ...             ...         ...         ...           ...   ...   ...
# 421565        58.85       3.882  192.308899         8.667    43  2012
# 421566        58.85       3.882  192.308899         8.667    43  2012
# 421567        58.85       3.882  192.308899         8.667    43  2012
# 421568        58.85       3.882  192.308899         8.667    43  2012
# 421569        58.85       3.882  192.308899         8.667    43  2012
#
# [421570 rows x 13 columns]

# %%
weekly_stores = df.groupby(['Store'])['Weekly_Sales'].mean().reset_index()

# %%
weekly_stores = weekly_stores.set_index('Store')

# %%
weekly_stores
# Out:
#        Weekly_Sales
# Store
# 1      21710.543621
# 2      26898.070031
# 3       6373.033983
# 4      29161.210415
# 5       5053.415813
# 6      21913.243624
# 7       8358.766148
# 8      13133.014768
# 9       8772.890379
# 10     26332.303819
# 11     19276.762751
# 12     14867.308619
# 13     27355.136891
# 14     28784.851727
# 15      9002.493073
# 16      7863.224124
# 17     12954.393636
# 18     15733.313136
# 19     20362.126734
# 20     29508.301592
# 21     11283.435496
# 22     15181.218886
# 23     19776.180881
# 24     18969.106500
# 25     10308.157810
# 26     14554.129672
# 27     24826.984536
# 28     18714.889803
# 29      8158.810609
# 30      8764.237719
# 31     19681.907464
# 32     16351.621855
# 33      5728.414053
# 34     13522.081671
# 35     13803.596986
# 36      8584.412563
# 37     10297.355026
# 38      7492.478460
# 39     21000.763562
# 40     13763.632803
# 41     17976.004648
# 42     11443.370118
# 43     13415.114118
# 44      6038.929814
# 45     11662.897315

# %%
weekly_stores.sort_values('Weekly_Sales').style.bar(align='left')
# Out:
# <style type="text/css">
# #T_0e4db_row0_col0 {
#   width: 10em;
# }
# #T_0e4db_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.8%, transparent 2.8%);
# }
# #T_0e4db_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.0%, transparent 4.0%);
# }
# #T_0e4db_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.4%, transparent 5.4%);
# }
# #T_0e4db_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.0%, transparent 10.0%);
# }
# #T_0e4db_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 11.5%, transparent 11.5%);
# }
# #T_0e4db_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.7%, transparent 12.7%);
# }
# #T_0e4db_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.5%, transparent 13.5%);
# }
# #T_0e4db_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.4%, transparent 14.4%);
# }
# #T_0e4db_row9_col0, #T_0e4db_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.2%, transparent 15.2%);
# }
# #T_0e4db_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.1%, transparent 16.1%);
# }
# #T_0e4db_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.4%, transparent 21.4%);
# }
# #T_0e4db_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 21.5%, transparent 21.5%);
# }
# #T_0e4db_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.5%, transparent 25.5%);
# }
# #T_0e4db_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.1%, transparent 26.1%);
# }
# #T_0e4db_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 27.0%, transparent 27.0%);
# }
# #T_0e4db_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.3%, transparent 32.3%);
# }
# #T_0e4db_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 33.0%, transparent 33.0%);
# }
# #T_0e4db_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.2%, transparent 34.2%);
# }
# #T_0e4db_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.6%, transparent 34.6%);
# }
# #T_0e4db_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.6%, transparent 35.6%);
# }
# #T_0e4db_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.8%, transparent 35.8%);
# }
# #T_0e4db_row23_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 38.8%, transparent 38.8%);
# }
# #T_0e4db_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.1%, transparent 40.1%);
# }
# #T_0e4db_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 41.4%, transparent 41.4%);
# }
# #T_0e4db_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 43.7%, transparent 43.7%);
# }
# #T_0e4db_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 46.2%, transparent 46.2%);
# }
# #T_0e4db_row28_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 52.8%, transparent 52.8%);
# }
# #T_0e4db_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 55.9%, transparent 55.9%);
# }
# #T_0e4db_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 56.9%, transparent 56.9%);
# }
# #T_0e4db_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.2%, transparent 58.2%);
# }
# #T_0e4db_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.8%, transparent 59.8%);
# }
# #T_0e4db_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.2%, transparent 60.2%);
# }
# #T_0e4db_row34_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 62.6%, transparent 62.6%);
# }
# #T_0e4db_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 65.2%, transparent 65.2%);
# }
# #T_0e4db_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.1%, transparent 68.1%);
# }
# #T_0e4db_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 68.9%, transparent 68.9%);
# }
# #T_0e4db_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 80.9%, transparent 80.9%);
# }
# #T_0e4db_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 87.0%, transparent 87.0%);
# }
# #T_0e4db_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 89.3%, transparent 89.3%);
# }
# #T_0e4db_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 91.2%, transparent 91.2%);
# }
# #T_0e4db_row42_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 97.0%, transparent 97.0%);
# }
# #T_0e4db_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 98.6%, transparent 98.6%);
# }
# #T_0e4db_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_0e4db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e4db_level0_col0" class="col_heading level0 col0" >Weekly_Sales</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Store</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e4db_level0_row0" class="row_heading level0 row0" >5</th>
#       <td id="T_0e4db_row0_col0" class="data row0 col0" >5053.415813</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row1" class="row_heading level0 row1" >33</th>
#       <td id="T_0e4db_row1_col0" class="data row1 col0" >5728.414053</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row2" class="row_heading level0 row2" >44</th>
#       <td id="T_0e4db_row2_col0" class="data row2 col0" >6038.929814</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0e4db_row3_col0" class="data row3 col0" >6373.033983</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row4" class="row_heading level0 row4" >38</th>
#       <td id="T_0e4db_row4_col0" class="data row4 col0" >7492.478460</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row5" class="row_heading level0 row5" >16</th>
#       <td id="T_0e4db_row5_col0" class="data row5 col0" >7863.224124</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row6" class="row_heading level0 row6" >29</th>
#       <td id="T_0e4db_row6_col0" class="data row6 col0" >8158.810609</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0e4db_row7_col0" class="data row7 col0" >8358.766148</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row8" class="row_heading level0 row8" >36</th>
#       <td id="T_0e4db_row8_col0" class="data row8 col0" >8584.412563</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row9" class="row_heading level0 row9" >30</th>
#       <td id="T_0e4db_row9_col0" class="data row9 col0" >8764.237719</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row10" class="row_heading level0 row10" >9</th>
#       <td id="T_0e4db_row10_col0" class="data row10 col0" >8772.890379</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row11" class="row_heading level0 row11" >15</th>
#       <td id="T_0e4db_row11_col0" class="data row11 col0" >9002.493073</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row12" class="row_heading level0 row12" >37</th>
#       <td id="T_0e4db_row12_col0" class="data row12 col0" >10297.355026</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row13" class="row_heading level0 row13" >25</th>
#       <td id="T_0e4db_row13_col0" class="data row13 col0" >10308.157810</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row14" class="row_heading level0 row14" >21</th>
#       <td id="T_0e4db_row14_col0" class="data row14 col0" >11283.435496</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row15" class="row_heading level0 row15" >42</th>
#       <td id="T_0e4db_row15_col0" class="data row15 col0" >11443.370118</td>
#     </tr>
#     <tr>
#       <th id="T_0e4db_level0_row16" class="row_heading level0 row16" >45</th>
#       <td id="T_0e4db_r

# %%
weekly_stores.values.reshape(-1,)
# Out:
# array([21710.54362066, 26898.07003126,  6373.03398296, 29161.21041472,
#         5053.41581287, 21913.24362354,  8358.76614833, 13133.01476806,
#         8772.89037893, 26332.30381871, 19276.76275094, 14867.30861927,
#        27355.13689135, 28784.85172709,  9002.49307343,  7863.22412369,
#        12954.39363646, 15733.31313622, 20362.12673433, 29508.30159193,
#        11283.43549572, 15181.21888625, 19776.1808806 , 18969.1064998 ,
#        10308.15781008, 14554.12967221, 24826.98453594, 18714.88980322,
#         8158.8106092 ,  8764.2377194 , 19681.90746401, 16351.62185454,
#         5728.41405272, 13522.08167058, 13803.59698573,  8584.41256348,
#        10297.35502637,  7492.47845966, 21000.76356246, 13763.63280323,
#        17976.0046481 , 11443.37011793, 13415.11411791,  6038.92981448,
#        11662.89731452])

# %%
#### 
plt.figure(figsize=(25,12))
sns.barplot(weekly_stores.index,weekly_stores.values.reshape(-1,),palette='dark')
plt.grid()
plt.xlabel('store number',fontsize=16)
plt.ylabel('weekly_Sales',fontsize=16)
plt.title('weekly sales per store',fontsize=30)
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weekly sales per store')

# %%
###########
week_dept = df['Weekly_Sales'].groupby(df['Dept']).mean()

# %%
week_dept = pd.DataFrame(week_dept)

# %%
week_dept
# Out:
#       Weekly_Sales
# Dept
# 1     19213.485088
# 2     43607.020113
# 3     11793.698516
# 4     25974.630238
# 5     21365.583515
# ...            ...
# 95    69824.423080
# 96    15210.942761
# 97    14255.576919
# 98     6824.694889
# 99      415.487065
#
# [81 rows x 1 columns]

# %%
week_dept.sort_values('Weekly_Sales',ascending=False).style.bar(align='left')
# Out:
# <style type="text/css">
# #T_0d5df_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_0d5df_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 92.8%, transparent 92.8%);
# }
# #T_0d5df_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 81.2%, transparent 81.2%);
# }
# #T_0d5df_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 67.2%, transparent 67.2%);
# }
# #T_0d5df_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.4%, transparent 60.4%);
# }
# #T_0d5df_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 60.1%, transparent 60.1%);
# }
# #T_0d5df_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 59.7%, transparent 59.7%);
# }
# #T_0d5df_row7_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 58.0%, transparent 58.0%);
# }
# #T_0d5df_row8_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.8%, transparent 44.8%);
# }
# #T_0d5df_row9_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 44.4%, transparent 44.4%);
# }
# #T_0d5df_row10_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.8%, transparent 40.8%);
# }
# #T_0d5df_row11_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 40.2%, transparent 40.2%);
# }
# #T_0d5df_row12_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 35.9%, transparent 35.9%);
# }
# #T_0d5df_row13_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 34.5%, transparent 34.5%);
# }
# #T_0d5df_row14_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 32.1%, transparent 32.1%);
# }
# #T_0d5df_row15_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 31.8%, transparent 31.8%);
# }
# #T_0d5df_row16_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 29.2%, transparent 29.2%);
# }
# #T_0d5df_row17_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 28.4%, transparent 28.4%);
# }
# #T_0d5df_row18_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.9%, transparent 26.9%);
# }
# #T_0d5df_row19_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 26.5%, transparent 26.5%);
# }
# #T_0d5df_row20_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 25.6%, transparent 25.6%);
# }
# #T_0d5df_row21_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 24.4%, transparent 24.4%);
# }
# #T_0d5df_row22_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.8%, transparent 20.8%);
# }
# #T_0d5df_row23_col0, #T_0d5df_row24_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.6%, transparent 20.6%);
# }
# #T_0d5df_row25_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 20.2%, transparent 20.2%);
# }
# #T_0d5df_row26_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.8%, transparent 19.8%);
# }
# #T_0d5df_row27_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.3%, transparent 19.3%);
# }
# #T_0d5df_row28_col0, #T_0d5df_row29_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 19.0%, transparent 19.0%);
# }
# #T_0d5df_row30_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 18.4%, transparent 18.4%);
# }
# #T_0d5df_row31_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.9%, transparent 17.9%);
# }
# #T_0d5df_row32_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 16.2%, transparent 16.2%);
# }
# #T_0d5df_row33_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 15.7%, transparent 15.7%);
# }
# #T_0d5df_row34_col0, #T_0d5df_row35_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 14.3%, transparent 14.3%);
# }
# #T_0d5df_row36_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 13.6%, transparent 13.6%);
# }
# #T_0d5df_row37_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 12.0%, transparent 12.0%);
# }
# #T_0d5df_row38_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.9%, transparent 10.9%);
# }
# #T_0d5df_row39_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 10.2%, transparent 10.2%);
# }
# #T_0d5df_row40_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.9%, transparent 9.9%);
# }
# #T_0d5df_row41_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.8%, transparent 9.8%);
# }
# #T_0d5df_row42_col0, #T_0d5df_row43_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 9.1%, transparent 9.1%);
# }
# #T_0d5df_row44_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.6%, transparent 8.6%);
# }
# #T_0d5df_row45_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 8.5%, transparent 8.5%);
# }
# #T_0d5df_row46_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.6%, transparent 7.6%);
# }
# #T_0d5df_row47_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.5%, transparent 7.5%);
# }
# #T_0d5df_row48_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 7.4%, transparent 7.4%);
# }
# #T_0d5df_row49_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.9%, transparent 6.9%);
# }
# #T_0d5df_row50_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.6%, transparent 6.6%);
# }
# #T_0d5df_row51_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.3%, transparent 6.3%);
# }
# #T_0d5df_row52_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 6.2%, transparent 6.2%);
# }
# #T_0d5df_row53_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.6%, transparent 5.6%);
# }
# #T_0d5df_row54_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.5%, transparent 5.5%);
# }
# #T_0d5df_row55_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 5.1%, transparent 5.1%);
# }
# #T_0d5df_row56_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.9%, transparent 4.9%);
# }
# #T_0d5df_row57_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.5%, transparent 4.5%);
# }
# #T_0d5df_row58_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.1%, transparent 4.1%);
# }
# #T_0d5df_row59_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.9%, transparent 3.9%);
# }
# #T_0d5df_row60_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.5%, transparent 3.5%);
# }
# #T_0d5df_row61_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.1%, transparent 3.1%);
# }
# #T_0d5df_row62_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.0%, transparent 3.0%);
# }
# #T_0d5df_row63_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.7%, transparent 2.7%);
# }
# #T_0d5df_row64_col0, #T_0d5df_row65_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.6%, transparent 2.6%);
# }
# #T_0d5df_row66_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.2%, transparent 2.2%);
# }
# #T_0d5df_row67_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 2.1%, transparent 2.1%);
# }
# #T_0d5df_row68_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 1.8%, transparent 1.8%);
# }
# #T_0d5df_row69_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.9%, transparent 0.9%);
# }
# #T_0d5df_row70_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.8%, transparent 0.8%);
# }
# #T_0d5df_row71_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.6%, transparent 0.6%);
# }
# #T_0d5df_row72_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.5%, transparent 0.5%);
# }
# #T_0d5df_row73_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.4%, transparent 0.4%);
# }
# #T_0d5df_row74_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.2%, transparent 0.2%);
# }
# #T_0d5df_row75_col0, #T_0d5df_row76_col0, #T_0d5df_row77_col0, #T_0d5df_row78_col0, #T_0d5df_row79_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 0.0%, tra

# %%
week_dept.values.reshape(-1,)
# Out:
# array([ 1.92134851e+04,  4.36070201e+04,  1.17936985e+04,  2.59746302e+04,
#         2.13655835e+04,  4.74785619e+03,  2.41612374e+04,  3.01912635e+04,
#         2.02066819e+04,  1.83212724e+04,  1.45056382e+04,  4.17539702e+03,
#         3.06638026e+04,  1.48709660e+04,  1.42456383e+04,  1.01871205e+04,
#         7.33694354e+03,  1.65481503e+03,  5.52878732e+03,  4.98285083e+03,
#         1.07745097e+04,  2.39314740e+04,  6.35360456e+03,  8.98823082e+03,
#         7.64941795e+03,  1.58343773e+03,  6.18085116e+02,  5.65365532e+03,
#         4.11819721e+03,  2.33944029e+03,  6.83327079e+03,  6.47197958e+03,
#         1.56259154e+04,  2.92104495e+03,  2.02257106e+03,  3.11107619e+03,
#         6.10906196e+04,  1.11237500e+01,  4.49007027e+04,  1.96556000e+03,
#         5.18970342e+03,  1.19333333e+00,  4.65172966e+03,  2.32115857e+01,
#         1.99447415e+04, -7.68255418e+00,  1.34489358e+03,  8.15995130e+03,
#         2.65889701e+03,  2.19317288e+01,  1.92835625e+03,  1.08305985e+02,
#         1.07166646e+04,  3.83370621e+03,  3.70290742e+03,  6.94463564e+02,
#         3.47370229e+02,  4.54417062e+04,  7.44068029e+03,  5.72292765e+03,
#         5.05665154e+04,  1.38074628e+04,  3.28961800e+02,  7.29663830e+00,
#         2.19730449e+04,  1.21836802e+04,  1.54704008e+04,  1.54696318e+04,
#         3.38334984e+03,  2.26435941e+03,  1.34188821e+04,  4.52320845e+04,
#         3.36879108e+04,  7.52048705e+04,  2.70080607e+04,  3.34058840e+04,
#         6.98244231e+04,  1.52109428e+04,  1.42555769e+04,  6.82469489e+03,
#         4.15487065e+02])

# %%
plt.figure(figsize=(25,12))
sns.barplot(week_dept.index,week_dept.values.reshape(-1,),palette='dark')
plt.grid()
plt.xlabel('dept',fontsize=16)
plt.ylabel('weekly_Sales',fontsize=16)
plt.title('weekly sales per department',fontsize=30)
# Out:
# C:\Users\khush\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'weekly sales per department')

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Type', 'Size',
#        'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'week', 'year'],
#       dtype='object')

# %%
df.groupby(['Type'])['Weekly_Sales'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Type'>

# %%
#### 
sns.boxplot(x='Type',y='Size',data=df)
# Out:
# <AxesSubplot:xlabel='Type', ylabel='Size'>

# %%
df.groupby(['year'])['Unemployment'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.groupby(['year'])['Weekly_Sales'].mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.groupby(['year'])['IsHoliday'].sum().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.groupby(['Dept'])['Unemployment'].sum()
# Out:
# Dept
# 1     51474.537
# 2     51474.537
# 3     51474.537
# 4     51474.537
# 5     50636.728
#         ...
# 95    51474.537
# 96    38100.479
# 97    50497.493
# 98    47338.673
# 99     6403.674
# Name: Unemployment, Length: 81, dtype: float64

# %%
df.groupby(['Dept'])['Unemployment'].sum().sort_values().head(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Dept'>

# %%
df.groupby(['Dept'])['Unemployment'].sum().sort_values().tail(10).plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Dept'>

# %% [raw]
# Insights
# 1. depratment 1 is having highest unemployment
# 2. department 43 is having lowest unemployment
# 3. type c stores are smaller in size, type a stores are larger in size
# 4. type a stores have higher avg sales, type c stores have lowest
# 5. store 20 have highest sales
# 6. store 5 have lowest sales.
# 7. every year the sales pattern is pretty same and in end of yesr highest sale is expected.
# 8. departmnet 92 is having highgest avg sales
# 9. department 47 is lowest avg sales.
# 10. high correlation between year and fuel price.
